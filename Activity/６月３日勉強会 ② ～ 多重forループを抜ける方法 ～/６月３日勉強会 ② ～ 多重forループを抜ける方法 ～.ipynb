# %% [markdown]
# ![代替えテキスト](https://enhancer298.net/wp-content/uploads/2020/06/e682d9ee2000e6b2a8229a38bb7fa050-2.jpg)

# %% [markdown]
# ###↓記事で用いたコードです。記事の順番に対応しているので実行してみて下さい！！

# %% [markdown]
# #####↓拳を一撃で止める

# %%
#1
for i in range(100):
  print("北斗百裂拳")
  break

# %% [markdown]
# #####↓みんな大好きあのキャラクターの名前の分割

# %%
#2
name = "Satoshi"
for master in name:
    print(master)

# %% [markdown]
# ######↓初代の冒険メンバーは？

# %%
#3
names = ["Satoshi", "Takeshi", "Kasumi"]
for character in names:
  print(character)

# %% [markdown]
# ####**↓食欲の地獄ループ**

# %%
#4
a = ["ドーナツ", "ケーキ", "ポテチ"]
b = ["食べたい", "食べよう","おいしかった"] 

for i in a: 
  for j in b: 
    print(i,j)

# %% [markdown]
# #####↓ループ脱出失敗

# %%
#5_ループ抜け失敗
a = ["ドーナツ", "ケーキ", "ポテチ"]
b = ["食べたい", "食べよう","おいしかった"] 

for i in a:
  for j in b:
    print(i,j)
    if i == "ケーキ" and j == "食べたい":
      break

# %% [markdown]
# #####↓ループ脱出成功！！

# %%
#6_ループ抜け成功
a = ["ドーナツ", "ケーキ", "ポテチ"]
b = ["食べたい", "食べよう","おいしかった"] 
mind = False

for i in a:
  for j in b:
    print(i,j)
    if i == "ケーキ" and j == "食べたい":
      mind = True
      break
  if mind:
    break

# %% [markdown]
# ####**↓実行すると恐ろしいことが起こる。。。**

# %%
#7_実行すると恐ろしいことが起こる
a = ["ドーナツ", "ケーキ", "ポテチ"]
b = ["食べたい", "食べよう","おいしかった"] 
mind = False

for i in a:
  for j in b:
    print(i,j)
    if i =="ポテチ" and j =="おいしかった":
      mind = True
  if mind :
    print("糖尿病になった")
  else :
    print("太った")
