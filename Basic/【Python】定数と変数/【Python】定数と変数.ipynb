# %%
5 + 5

# %%
5 - 5

# %%
5 / 5

# %%
5 * 5

# %%
x = 1
x

# %%
x = 1
x 

x = 10
x

# %%
x = 1
x = x + 1
x

# %%
x = 1
x = x - 1
x

# %%
x = 1
x += 1
x

# %%
x = 1
x -= 1
x

# %%
str = "こんにちは"
str

# %%
float = 1.1
float

# %%
bool = True
bool

# %%
for_example = ("アンダースコアを入れよう")
for_example
