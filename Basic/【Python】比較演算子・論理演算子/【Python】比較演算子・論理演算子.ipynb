# %%
20 > 10
20 < 30
20 >= 19
20 <= 21
20 == 20
20 != 10

# %%
20 > 10

# %%
20 < 30

# %%
20 >= 19

# %%
20 <= 21

# %%
20 == 20

# %%
x = 100
print(x)

# %%
20 != 10

# %%
10 <= 7

# %%
10 <= 20

# %%
100 == 100 and 50 == 50

# %%
100 == 100 and 50 == 50

# %%
100 == 100 and 50 == 100

# %%
100 == 100 or 50 == 100

# %%
100 == 100 or 50 == 50

# %%
100 == 10 or 100 == 50

# %%
not 10 == 10

# %%
not 10 == 11
