# %%
x = ["おはよう","こんにちは","こんばんは"]
x
# Out:
# ['おはよう', 'こんにちは', 'こんばんは']

# %%
x = ["おはよう","こんにちは","こんばんは"]
x.append("さようなら")
x.append("おやすみ")
x
# Out:
# ['おはよう', 'こんにちは', 'こんばんは', 'さようなら', 'おやすみ']

# %%
x = [False, 10, 0.1,"こんにちは"]
x
# Out:
# [False, 10, 0.1, 'こんにちは']

# %%
x = ["おはよう","こんにちは","こんばんは"]
x[0]
# Out:
# 'こんばんは'

# %%
x = ["おはよう","こんにちは","こんばんは"]
print(x[0])
print(x[1])
print(x[2])
# Out:
# おはよう
# こんにちは
# こんばんは

# %%
x = ["おはよう","こんにちは","こんばんは"]
x[2] = "さようなら"
x
# Out:
# ['おはよう', 'こんにちは', 'さようなら']

# %%
x = ["おはよう","こんにちは","さようなら"]
y = x.pop()
x
# Out:
# ['おはよう', 'こんにちは']

# %%
pp = ["pineapple","pen"]
ap = ["apple","pen"]
pp + ap
# Out:
# ['pineapple', 'pen', 'apple', 'pen']

# %%
x = ["おはよう","こんにちは","こんばんは"]
"こんばんは" in x
# Out:
# True

# %%
x = ["おはよう","こんにちは","こんばんは"]
"こんばんは" not in x
# Out:
# False

# %%
x = ["おはよう","こんにちは","さようなら"]
len(x)
# Out:
# 3
