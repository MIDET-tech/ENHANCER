# %%
import csv

with open("french.csv", "w") as x:
  y = csv.writer(x, delimiter=",")
  y.writerow(["un", "due", "tour"])
  y.writerow(["quatre", "cinq", "six"])

# %%
import csv

with open("french.csv", "r") as x:
  y = csv.reader(x, delimiter=",")
  for z in y:
    print(",".join(z))
# Out:
# un,due,tour
# quatre,cinq,six
