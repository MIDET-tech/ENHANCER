# %%
x = ()
x
# Out:
# ()

# %%
x = ("こんにちは","おはよう",100)
x
# Out:
# ('こんにちは', 'おはよう', 100)

# %%
x = ("こんにちは","おはよう","さようなら")
x[1] = "やあ"

# %%
x = ("こんにちは","おはよう","さようなら")
x[2]
# Out:
# 'さようなら'

# %%
x = ("こんにちは","おはよう","さようなら")
"おはよう" in x
# Out:
# True

# %%
x = {"くだもの": "みかん","あいさつ": "おはよう"}
x
# Out:
# {'あいさつ': 'おはよう', 'くだもの': 'みかん'}

# %%
x = {"くだもの": "みかん","あいさつ": "おはよう"}
x["やさい"] = "にんじん"
x
# Out:
# {'あいさつ': 'おはよう', 'くだもの': 'みかん', 'やさい': 'にんじん'}

# %%
x = {"くだもの": "みかん","あいさつ": "おはよう"}
x["くだもの"]
# Out:
# 'みかん'

# %%
x = {"くだもの": "みかん","あいさつ": "おはよう"}
"くだもの" in x
# Out:
# True

# %%
x = {"くだもの": "みかん","あいさつ": "おはよう"}
"くだもの" not in x
# Out:
# False

# %%
x = {"くだもの": "みかん", "あいさつ": "おはよう"} 
del x["くだもの"]
x
# Out:
# {'あいさつ': 'おはよう'}
