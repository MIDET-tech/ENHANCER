# %% [markdown]
# ![代替えテキスト](https://enhancer298.net/wp-content/uploads/2020/06/f97b64d1eebcd7460f5a785aa1bac0d3-1-e1592731738580.jpg)

# %% [markdown]
# ###↓記事で用いたコードです。記事の順番に対応しているので実行してみて下さい！！

# %% [markdown]
# ####文字列とは

# %%
#文字列
"こんにちは！"

# %%
#文字列から特定の文字を抽出する
my_name = "Peng"
my_name[0]

# %% [markdown]
# ####文字列の最初と最後の空白を除去する

# %%
your_name = "　        君の名前は            "
your_name = your_name.strip()
your_name

# %% [markdown]
# ####文字列の特定の文字を入れ替える

# %%
character = "アソパソマソ"
character = character.replace("ソ", "ン")
character

# %% [markdown]
# ####文字列の特定の文字を探す

# %%
"Peng".index("e")

# %%
#変数の中の文字を取り出す
name = "Takeshi"
name.index("T")

# %%
#エラーが表示される
name.index("x")

# %%
#エラーが出た場合に出力されるコードを入力する。
try:
  print(name.index("x"))
except:
  print("この文字列にxはありません")

# %% [markdown]
# ####文字列に特定の文字が入っているか確かめる

# %%
"pen" in "I have a pen."

# %%
"apple" in "I have a pen."

# %%
"p" in "I have a pen."

# %% [markdown]
# ####文字列を改行する

# %%
print("ホップ\nステップ\nジャンプ")

# %% [markdown]
# ####文字列の中の特定の文字列を取り出す

# %%
dish = "昨日の夕食はカレー"
dish[0:5]

# %%
#最初から７文字目まで
dish[:6]

# %%
#３文字目から最後まで
dish[3:]

# %%
#ルーを買い忘れる
pur = ["ジャガイモ", "ニンジン", "タマネギ", "牛肉", "ルー"]
pur[0:4]

# %%
#これでおいしいカレーが作れる
pur = ["ジャガイモ", "ニンジン", "タマネギ", "牛肉", "ルー"]
pur[0:5]

# %% [markdown]
# ###練習問題答え

# %%
#1.文字列 "I have a pen" の a を ＠に変えてみましょう。
sent = "I have a pen"
sent = sent.replace("a", "@")
sent

# %%
#自分の名前をローマ字で入力し、"a"が出現するインデックス番号を出力しよう。また、"a"が入っていない場合に出力される文字列を作ろう。
myname = "Peng"
try:
  print(myname.index("a"))
except:
  print("名前にaは含まれていません。")

# %%
#相手に血液型を訪ね、入力値を大文字にした後、A型の時にある文字を出力し、それ以外の時にある文字を出力するコードを書こう。
#もし余力があれば、それぞれの血液型の入力に対してそれぞれメッセージを書こう。
blood = input("あなたの血液型は？")
blood = blood.upper()
if "AB" in blood:
  print("あなたはAB型です")
elif "A" in blood:
  print("あなたはA型です")
elif "B" in blood:
  print("あなたはB型です")
elif "O" in blood:
  print("あなたはO型です")
else:
  print("アルファベットを入力してください")

# %%
#Pythonとい文字列で「P」から「t」までを出力するコードを書こう。
prog = "Python"
prog[:3]
