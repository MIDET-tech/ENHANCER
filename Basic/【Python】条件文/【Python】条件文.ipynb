# %%
x = "こんにちは" 
if x == "こんにちは": 
  print("こんにちは")
else: 
  print("こんばんは")

# %%
x = 10 
if x == 10: 
  print("正解です") 
if x * 2 != 20: 
  print("答えは20ではありません") 
if x / 2 == 5: 
  print("答えは5です")

# %%
x = 10 
y = 5 
if x == 10: 
  if y == 5: 
    print(x * y)

# %%
x = 10 
if x == 5: 
  print("数字は5です") 
elif x == 7: 
  print("数字は7です") 
elif x == 10: 
  print("数字は10です") 
else: 
  print("これは数字です")

# %%
x = 10 
if x == 5: 
  print("数字は5です") 
elif x == 7: 
  print("数字は7です") 
elif x == 10: 
  print("数字は10です") 
else: print("これは数字です") 

x = "こんにちは" 
if x == "こんにちは": 
  print("こんにちは") 
else: 
  print("こんばんは")
