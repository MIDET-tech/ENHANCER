# %%
x = 0b0111
y = 0b0100
z = x | y
print(z)

# %%
z = x | y

# %%
print(z)

# %%
print(bin(z))

# %%
x = 0b0111
y = 0b0100
z = x ^ y
print(z)

# %%
x = 0b0111
y = 0b0100
z = x & y
print(z)

# %%
~1

# %%
x = 0b0111
y = ~x
print(y)

# %%
x = 0b0111
y = ~x
print(y)

# %%
x = 0b0111
y = x >> 2
print(bin(y))
