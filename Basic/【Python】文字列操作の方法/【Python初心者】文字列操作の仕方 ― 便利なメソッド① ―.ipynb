# %% [markdown]
# ###↓記事で用いたコードです。記事の順番に対応しているので実行してみて下さい！！

# %% [markdown]
# ####文字列を入力する

# %%
"こんにちは！"

# %%
#エラーが表示される
こんにちは！

# %% [markdown]
# ####複数行の文字列を書く

# %%
"こんにちは！"
"僕の名前はPengです"

# %%
#自由に改行できる
""" こんにちは！
　　僕の名前はPengです
"""

# %% [markdown]
# ####文字列から文字を抽出する

# %%
my_name = "Peng"

print(my_name[0])
print(my_name[1])
print(my_name[2])
print(my_name[3])

# %%
#後ろから数える
my_name = "Peng"

print(my_name[-4])
print(my_name[-3])
print(my_name[-2])
print(my_name[-1])

# %% [markdown]
# ####文字列の足し算、掛け算

# %%
"僕は" + "昨日" + "たくさん寝ました"

# %%
"北斗百裂拳" * 100

# %% [markdown]
# ####大文字、小文字の変換

# %%
#大文字に変換
"I have a pen.".upper()

# %%
#小文字に変換
"PENGUIN".lower()

# %%
#先頭の文字だけ大文字
"python".capitalize()

# %% [markdown]
# ####文字列の一部を穴埋めする

# %%
"こんにちは！、{}です！".format("あなたの名前")

# %%
name = "あなたの名前"
"こんにちは！、{}です！".format(name)

# %%
"この{}は{}です".format("鳥", "ペンギン")

# %%
names = input("あなたの名前は？")
birth = input("あなたの生まれた年は？")
age = input("あなたの年齢は？")

"私の名前は{}です。{}年に生まれました。私は今{}歳です。".format(names, birth, age)

# %% [markdown]
# ####文字列を分割する

# %%
#"、"で文章を分割
"最初に海に飛び込むペンギンは、ファーストペンギンと呼ばれる".split("、")

# %%
#"に"で文章を分割
"最初に海に飛び込むペンギンは、ファーストペンギンと呼ばれる".split("に")

# %% [markdown]
# ####文字列の間に文字を入れたり、結合したりする

# %%
god = "トト"
veg = "マ".join(god)
veg

# %%
fault = "マボドフ"
dish = "ー".join(fault)
dish

# %%
sent = ["僕は", "昨日", "カレーライスを", "食べたんだよ"]
par = "ね、".join(sent)
par

# %% [markdown]
# ####*文字列の最初と最後の空白を除去する*

# %%
your_name ="        君の名前は            "
your_name = your_name.strip()
your_name

# %% [markdown]
# ####文字列の文字を入れ替える

# %%
character = "アソパソマソ"
character = character.replace("ソ", "ン")
character

# %% [markdown]
# ####文字列の文字を探す

# %%
"Peng".index("e")

# %% [markdown]
# ###練習問題答え

# %%
#1.文字列 "Penguin" の "u" のインデックス番号を出力しよう。
pen = "Penguin"
pen[4]

# %%
#2.三つの文字列を足したり掛けたりして、"今日はルンルン気分"と出力しよう。 
"今日は" + "ルン" * 2 + "気分"

# %%
#3.文字列の入力を受け取り、誰が、いつ、どこで、どうした、を文章として出力しよう。（※ヒント：format() を使おう。○は○に○で○）
who = input("誰が:")
when = input("いつ：")
where = input("どこで：")
do = input("どうした:")

"{}は{}に{}で{}".format(who, when, where, do)

# %%
#.4好きな文字列を好きな文字で分割した後、"+"でそれぞれを結合しよう。
st = "Penguin"
st = st.split("g")
st = "+".join(st)
st
